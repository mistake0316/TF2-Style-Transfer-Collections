# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("Style/Mosaic_ducks.jpeg")

# %%
plt.imshow(img[200:850:,200:850,::-1])

# %%
cv2.imwrite("Style/Mosaic_ducks_crop.jpeg",img[200:850:,200:850])
# Out:
# True
